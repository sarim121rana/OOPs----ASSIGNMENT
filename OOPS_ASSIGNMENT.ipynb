# %% [markdown]
# # PYTHON OOPS ASSIGNMENT.

# %% [markdown]
# Q.1 What is Object-Oriented Programming (OOP)?
#   - Object oriented programming (OOPS) is a programming paradigm that organizes software design around data structures called objects, which encapsulate both data and behaviour through functions called methods.
#   - It organizes code using objects and classes to model real-world entities and behaviors.

# %% [markdown]
# Q.2 What is a class in OOP ?
#  -  In OOP(object oriented prograaming), a class is like a blueprint or template that defines how an object should look like and behave.

# %% [markdown]
# Q.3 What is an object in OOP ?
#   - In OOP(object oriented programming), an object is a real-world instance of a class.
#   -  Each object has its own data attribute and can perform actions(methods) defines in the class.

# %% [markdown]
# Q.4 What is the difference between abstraction and encapsulation ?
#    - ABSTRACTION -->>
#    - Hiding the implementation details and showing the essential features to the user.
#    - Example(Real life) : When you drive a car you just use the steering,wheel,breaks, and accelerator.
#    - you don't know the internal engine mechanism - that part is abstracted.
#    - ENCAPSULATION -->>
#    - Wrapping the data (variable) and methods (functions) together into a single unit (class)
#    - focus on hiding the data (information hiding) by restricting direct access.
#    - Achived using access modifiers (private,protected,public).

# %% [markdown]
# Q.5 What are dunder methods in Python ?
#   - DUNDER = Double UNDERscores.
#   - They are the special methods in python that start and end with two underscores(___ method __).
#   - Also caleed magic methods.
#   -  They let you customize how objects of a class behave with operators, functions, or built-in features.

# %% [markdown]
# Q.6 Explain the concept of inheritance in OOP  ?
#   - Inheitance is an OOPS concepts where a class (child/derived class) can reuse properties and methods from another class (parent/base class).
#   - It allows code reuseability.
#   -  Helps in creating a hierarchy (general --> specific).
#   - Parent class in inherited by child class.

# %% [markdown]
# Q.7 What is polymorphism in OOP ?
#   - Polymorphism means "many forms" in OOPS. it allows the same functions/method name to behave differently depending on the object or situation.
#   - In short : one name, many behaviours.

# %% [markdown]
# Q.8 How is encapsulation achieved in Python ?
#   - Encapsulation means binding data (variable) and methods (functions) together and restricting direct access to the data.
#   - In python, encapsulation is achieved mainly through access modifiers.
#   1. Public members :-->>
#   -  Accessible from anywhere
#   - Default in python
#   2.  Protected members :-->>
#   -  Indicated with a single underscore (_variable).
#   -  Conventially should not be accessed directly, but still accessible.
#   -  Treated as "protected" (intended for use within class and subclasses).
#   3. Private members : -->>
#   -  Indicated with double underscore(__variable).
#   -  Name mangling makes it hard to access directly.

# %% [markdown]
# Q.9 What is a constructor in Python
#   - A construter is a special type of method in python used to initialize object when a class is created.
#   - It is defined using the (__init __) method.
#   - Runs automatically when you create an object.
#   -  Used to set an initial values for object attributes.

# %% [markdown]
# Q.10 What are class and static methods in Python ?
#   - CLASS METHOD : -->>
#   -  A class method is a method that works with the class itself rather than an object.
#   - it uses @classmethod decorator.
#   - Takes cls(class reference) as the first parameter instead of self.
#   - Can access and modify class-level variables, but not instance-level ones.
#   - STATIC METHOD :-->>
#   - A static method is a method that does not depend in the class or object.
#   - it uses @staticmethod decorator
#   - Does not take self (object reference ) or cls (class reference).
#   -  Works like a normal function inside a class (for logical grouping.)

# %% [markdown]
# Q.11 What is method overloading in Python ?
#  -  Method overloading means having multiple methods with the same name but different parameters (number or tyoes of arguments.)
#  -  In python , true method overloading does not exist.
#  -  Why ? Because if you define two methods with the same name, the last one overrides the previous one.

# %% [markdown]
# Q.12 What is method overriding in OOP ?
#   - Method overriding happens when a child class provides a new implementation of a method that already exists in the parent class.
#   -  The method name and parameters are the same as in the parent.
#   -  The childs's method replaces (overrides) the parent's method when called through a child object.
#   -  This is a type of runtime polymorphism.

# %% [markdown]
# Q.13 What is a property decorator in Python ?
#   - In python, a property decorator (@property) is used to turn a class method into a read only attributes.
#   - It lets you access methods like attributes (without parentheses).
#   -  Often used for getter, setter, deleter to implement encapsulation more cleanly.

# %% [markdown]
# Q.14 Why is polymorphism important in OOP ?
#   - Polymorphism = " one name. many forms. "
#   - It allows the same method or operator to work differently based on the object.
#   - This makes OOPS code flexibile, reuseable ,and easier to extend .

# %% [markdown]
# Q.15 What is an abstract class in Python ?
#   - An abstract class is a blueprint for other classes.
#   - It can have abstract methods (declared but not implemented).
#   - A class containing at least one abstract method becomes an abstract class.
#   - Abstract class cannot be instantiated (you cannot create objects from them).
#   - They are used to enforce a contract: child classes must implemented cetain methods.

# %% [markdown]
# Q.16 What are the advantages of OOP ?
#   - Advantages of the OOP are :-->>
#      1. Modularity (code Reuseability)
#      2. Encapsulation (Data Security)
#      3. Abstraction (Hides Complexity)
#      4. Polymorphism (Flexibility)
#      5. Inheritance (code extentsibility)
#      6. Improved mentality
#      7. Scalability
#      8. Real-world modeling.

# %% [markdown]
# Q.17 What is the difference between a class variable and an instance variable ?
#   - Class Variable :-->>
#     -  A variable that belongs to the class, shared by all objects.
#     - It is defined inside the class but outside any method.
#     - Only one copy is stored and shared across all objects.
#     -  It is used when you want a property common foe all objects.
#   - Instance Variables :-->>
#     -  A variable that belongs to a specific object (instance)
#     - It is defined inside the constructor (__init__) or methods using self.
#     - Each object has its own copy.
#     - It is used when you want data unique to each object.

# %% [markdown]
# Q.18 What is multiple inheritance in Python ?
#
#   - Multiple inheritance means a class can inherit from more than one parent class.
#   - The child class gets access attributes and methods of all parent classes.
#   - python fully support multiple inheritance.

# %% [markdown]
# Q.19 Explain the purpose of ‘__str__’ and ‘__repr__’ ‘ methods in Python ?
#   - __str __
#
#     - Returns a user-friendly string representation of an object.
#     - meants for end-users.
#     - called by print(obj) or str(obj)
#     - Easy to read, readable format.
#   - __repr __
#     - Return an official / developer friendly string representation of object.
#     - meants for developers / debugging.
#     - called by repr (obj) or just typing object in interactive shell.
#     - precise and unambiguous, ideally can recreate the object.

# %% [markdown]
# Q.20 What is the significance of the ‘super()’ function in Python ?
#   - super allows you to call methods pr access properties of a parent class from a child class.
#   -  commonly used in method overriding and multiple inheritance.
#   -  Ensure parent class methods are executed without explicity naming parent.
#   - Avoids Hardcoding parent class name
#   - works well with multiple inheritance
#   - code reuseability

# %% [markdown]
# Q.21 What is the significance of the __del__ method in Python ?
#   - __del__ is a destructor method in python.
#   - it is called automatically when an object is about to be destroyed (i.e, garbage collected).
#   - usually used to release resources like files, network connections, or database connections.

# %% [markdown]
# Q.22 What is the difference between @staticmethod and @classmethod in Python ?
#   - @staticmethod :-->>
#     -  first parameter None
#     -  Cannot access class or instance attributes.
#     - Utility/helper function related to class, but indipendent of class/ instance.
#     - Decorator is @staticmethod
#     - Called by the class or instance.
#     - Does not depend on the class or object state.
#   - @classmethod :-->>
#     - First parameter is cls (class itself)
#     - can access class attributes, but not instance attributes.
#     - methods that work with class variables or factory methods.
#     - Decorator is @classmethod
#     - called by the class or instance
#     - Can modify class state, not instance state.

# %% [markdown]
# Q.23 How does polymorphism work in Python with inheritance ?
#   - When a child class overrides a method from the parent class, python decides which method to call at runtime based on the object.
#   -  This is called run-time polymorphism (method overriding)

# %% [markdown]
# Q.24 What is method chaining in Python OOP ?
#   - Method chaining means calling multiple methods on the same object in a single line by returning the objects (self) from each method.
#   - It is commonly used in fluent interfaces(like Pandas, SQLAIchemy, etc.) to make code more concise and readable.

# %% [markdown]
# Q.25 What is the purpose of the __call__ method in Python ?
#   - __call__ is a special type of the dunder method in python.
#   - If a class defines __call__, its objects can be called like functions.
#   - Makes instance callable.

# %% [markdown]
# #practical Questions

# %%
#Q.1 :-->> Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
#      that overrides the speak() method to print "Bark!".
class Animal:
    def speak(self):
        print("Generic animal sound")

class Dog(Animal):
    def speak(self):
        print("Bark")

a=Animal()
a.speak()
# Out:
# Generic animal sound

# %%
d=Dog()
d.speak()
# Out:
# Bark

# %%
 #  Q.2 :-->>  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
 #         from it and implement the area() method in both.
from abc import ABC, abstractmethod
import math

#Abstract class
class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

#Derived class
class Circle(Shape):
  def __init__(self,radius):
      self.radius = radius

  def area(self):
      return math.pi * self.radius * self.radius

#Derived class rectangle
class Rectangle(Shape):
    def __init__(self,length, width):
      self.length = length
      self.width = width
    def area(self):
      return self.length * self.width

#Example usage
c=Circle(5)
print("Area of circle :",c.area())
r=Rectangle( 4,5)
print("Area of rectangle:",r.area())
# Out:
# Area of circle : 78.53981633974483
# Area of rectangle: 20

# %%
# Q.3 :-->>>  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
#    and further derive a class ElectricCar that adds a battery attribute.


#Base class
class Vehicle:
  def __init__(self,vehicle_type):
        self.type=vehicle_type

#Derived class
class Car(Vehicle):
  def __init__(self, vehicle_type, brand):
    super().__init__(vehicle_type)
    self.brand=brand

#Further derived class
class ElectricCar(Car):
  def __init__(self, vehicle_type, brand, battery):
    super().__init__(vehicle_type, brand) # Pass only vehicle_type and brand to Car.__init__
    self.battery=battery

  def display_info(self):
    print(f"Type:{self.type}, brand :{self.brand}, Battery: {self.battery} kwh")

ecar=ElectricCar("Electric", "Tesla", 75)
ecar.display_info()
# Out:
# Type:Electric, brand :Tesla, Battery: 75 kwh

# %%
# Q.4 :-->> Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

class Bird:
  def fly(self):
    print("Birds can usually fly")

class Sparrow(Bird):
  def fly(self):
    print("Sparrow flies high in the sky")


class Penguin(Bird):
  def fly(self):
    print("penguin can't fly, They swim instead")


birds=[Sparrow(), Penguin()]
for bird in birds:
  bird.fly()
# Out:
# Sparrow flies high in the sky
# penguin can't fly, They swim instead

# %%
# Q.5 :-->> Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#            balance and methods to deposit, withdraw, and check balance.

class BankAccount:
  def __init__(self, initial_balance=0):
    self.__balance=initial_balance


  def deposit(self,amount):
    if amount > 0:
      self.__balance += amount
      print(f"Deposited: {amount}")
    else:
      print("Deposit amount must be positive")


  def withdraw(self, amount):
    if 0 < amount <= self.__balance:
      self.__balance -= amount
      print(f"Withdrew: {amount}")
    else:
      print("Insufficient balance")

  def get_balance(self):
    return self.__balance


account=BankAccount(1000)

account.deposit(500)
account.withdraw(200)


print("Current balance:", account.get_balance())
# Out:
# Deposited: 500
# Withdrew: 200
# Current balance: 1300

# %%
# Q.6 :-->> Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
#           and Piano that implement their own version of play()


class Instrument:   #Base class
  def play(self):
    print("Generic instrument sound")

class Guitar(Instrument):  #Derived class 1
  def play(self):
    print("strumming the guitar")

class Piano(Instrument):    #Derived class 2
  def play(self):
    print("Playing the piano")

#Example usage
instrument = [Guitar(), Piano()]

for instr in instrument:
  instr.play()   #Runtime polymorphism in action.
# Out:
# strumming the guitar
# Playing the piano

# %%
# Q.7 :-->> Create a class MathOperations with a class method add_numbers() to add two numbers and a static
#           method subtract_numbers() to subtract two numbers.

class MathOperations:
  @classmethod
  def add_numbers(cls, a, b):
    return a + b

  @staticmethod
  def subtract_numbers(a, b):
    return a - b

print("Additon:", MathOperations.add_numbers(10,5))

print("Subtraction:",MathOperations.subtract_numbers(10,5))
# Out:
# Additon: 15
# Subtraction: 5

# %%
# Q.8 :-->> Implement a class Person with a class method to count the total number of persons created.

class Person:
  count = 0

  def __init__(self, name):
    self.name = name
    Person.count += 1

  @classmethod
  def total_persons(cls):
    return cls.count


p1=Person("Sarim")
p2=Person("Rana")
p3=Person("Rajput")


print("Total Persons Created:", Person.total_persons())
# Out:
# Total Persons Created: 3

# %%
#  Q.9 :-->> Write a class Fraction with attributes numerator and denominator. Override the str method to display the
#             fraction as "numerator/denominator".

class Fraction:
  def __init__(self, numerator, denominator):
    self.numerator = numerator
    self.denominator = denominator

  def __str__(self):
    return f"{self.numerator} / {self.denominator}"

# Example usage
f1 = Fraction(3, 4)
f2 = Fraction(7, 8)

print(f1)
print(f2)
# Out:
# 3 / 4
# 7 / 8

# %%
# Q.10 :-->> Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
#            vectors


class Vector:
  def __init__(self, x, y):
    self.x = x
    self.y = y

  def __add__(self,other):
    return Vector(self.x + other.x, self.y + other.y)

  def __str__(self):
    return f"({self.x},{self.y})"


v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2

print("Vector 1:", v1)
print("Vector 2:", v2)
print("Vector 3:", v3)
# Out:
# Vector 1: (2,3)
# Vector 2: (4,5)
# Vector 3: (6,8)

# %%
#Q.11 :-->>. create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
#            {name} and I am {age} years old."

class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def greet(self):
    print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p1 = Person("Alice", 20)
p2 = Person("Bob", 30)

p1.greet()
p2.greet()
# Out:
# Hello, my name is Alice and I am 20 years old.
# Hello, my name is Bob and I am 30 years old.

# %%
# Q.12 :-->> Implement a class Student with attributes name and grades. Create a method average_grade() to compute
#             the average of the grades.

class Student:
  def __init__(self, name, grades):
    self.name = name
    self.grades = grades

  def average_grade(self):
    if len(self.grades) == 0:
      return 0
    return sum(self.grades) / len(self.grades)

s1 = Student("Sarim", [85, 90, 78, 92])
s2 = Student("Saniya",[70, 65, 80, 98])

print(f"{s1.name}'s average grade:", s1.average_grade())
print(f"{s2.name}'s average grade:", s2.average_grade())
# Out:
# Sarim's average grade: 86.25
# Saniya's average grade: 78.25

# %%
# Q.13 :-->>. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
#             area.

class Rectangle:
  def __init__(self):
    self.length = 0
    self.width = 0

  def set_dimensions(self, length, width):
    self.length = length
    self.width = width

  def area(self):
    return self.length * self.width


rect = Rectangle()
rect.set_dimensions(10, 5)

print("Area of Rectangle:", rect.area())
# Out:
# Area of Rectangle: 50

# %%
# Q.14 :-->> Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
#            and hourly rate. Create a derived class Manager that adds a bonus to the salary

class Employee:
  def __init__(self, name, hours_worked, hourly_rate):
    self.name = name
    self.hours_worked = hours_worked
    self.hourly_rate = hourly_rate

  def calculate_salary(self):
    return self.hours_worked * self.hourly_rate


class Manager(Employee):
  def __init__(self, name, hours_worked, hourly_rate, bonus):
    super().__init__(name, hours_worked, hourly_rate)
    self.bonus = bonus

  def calculate_salary(self):
    base_salary = super().calculate_salary() + self.bonus


emp = Employee("Sarim", 40, 20)
mang = Manager("Saniya", 40, 30, 500)

print(f"{emp.name}'s salary: $", emp.calculate_salary())
print(f"{mang.name}'s salary: $ ", mang.calculate_salary())
# Out:
# Sarim's salary: $ 800
# Saniya's salary: $  None

# %%
# Q.15 :-->> 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
#                calculates the total price of the product.

class Product:
  def __init__(self, name, price, quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    return self.price * self.quantity

p1 = Product("SmartPhone", 6700, 7)
p2 = Product("Headsphone", 390, 5)

print(f"Total price of {p1.name}: $", p1.total_price())
print(f"Total price of {p2.name}: $", p2.total_price())
# Out:
# Total price of SmartPhone: $ 46900
# Total price of Headsphone: $ 1950

# %%
# Q.16 :-->> Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
#            implement the sound() method.

from abc import ABC, abstractmethod
class Animal:
  @abstractmethod
  def sound(self):
    pass

class Cow(Animal):
  def sound(self):
    return "Moo Moo"

class Sheep(Animal):
  def sound(self):
    return "Baaa Baaa"

c = Cow()
s = Sheep()

print("Cow sound:", c.sound())
print("Sheep sound:", s.sound())
# Out:
# Cow sound: Moo Moo
# Sheep sound: Baaa Baaa

# %%
# Q.17 :-->> Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
#            returns a formatted string with the book's details.

class Book:
  def __init__(self, title, author, year_published):
    self.title = title
    self.author = author
    self.year_published = year_published

  def get_book_info(self):
    return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"


b1 = Book("The Great Gatsby", "F. Scott Fitzgerald", 1925)
print(b1.get_book_info())
# Out:
# Title: The Great Gatsby
# Author: F. Scott Fitzgerald
# Year Published: 1925

# %%
#Q.18 :-->>. Create a class House with attributes address and price. Create a derived class Mansion that adds an
#            attribute number_of_rooms.

class House:
  def __init__(self, address, price):
    self.address = address
    self.price = price

  def display_info(self):
    return f"Address: {self.address}, price: {self.price} INR"


class Mansion(House):
  def __init__(self, address, price, number_of_rooms):
    super().__init__(address, price)
    self.number_of_rooms = number_of_rooms

  def display_info(self):
    return f"Address: {self.address}, price: {self.price} INR, Rooms: {self.number_of_rooms}"

h1 = House("Delhi, India", 5000000)
h2 = Mansion("Mumbai, India",20000000, 12)

print(h1.display_info())
print(h2.display_info())
# Out:
# Address: Delhi, India, price: 5000000 INR
# Address: Mumbai, India, price: 20000000 INR, Rooms: 12
